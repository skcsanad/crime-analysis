# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from pandas.tseries.holiday import USFederalHolidayCalendar
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from torch.nn import functional as F
import torch
from torchvision import datasets, transforms
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from kneed import KneeLocator
import matplotlib.cm as cm

# %%
# Loading data
inputFeature = pd.read_csv('../Data/NIBRS_ND_2021/processed/input.csv', index_col='Unnamed: 0')
# Separating numerical and categorical features
numerical_features=['population','victim_seq_num','age_num_victim','incident_hour','incident_month','incident_day','incident_dayofmonth','incident_weekofyear']
categorical_features = ['resident_status_code','race_desc_victim',
'ethnicity_name_victim','pub_agency_name','offense_name','location_name','weapon_name'
,'injury_name','relationship_name','incident_isweekend']
# Onehot-encoding categorical features
inputFeature_1h = pd.get_dummies(inputFeature, columns=categorical_features)

# %%
# Convert object columns to numeric if they represent categories
for column in inputFeature_1h.select_dtypes(include=['object']):
    inputFeature_1h[column] = inputFeature_1h[column].astype('category').cat.codes

# Train-test split
train, test = train_test_split(inputFeature_1h, test_size=0.1, random_state=42)

# Normalizing numerical features
for feature in numerical_features:
  train[feature] = (train[feature] - train[feature].min()) / (train[feature].max() - train[feature].min())
  test[feature] = (test[feature] - test[feature].min()) / (test[feature].max() - test[feature].min())

# Converting data to tensors
X_train = torch.nan_to_num(torch.Tensor(train.values.astype(np.float32)))
y_train = torch.nan_to_num(torch.Tensor(train.values.astype(np.float32)))

X_test = torch.nan_to_num(torch.Tensor(test.values.astype(np.float32)))
y_test = torch.nan_to_num(torch.Tensor(test.values.astype(np.float32)))

# %%
# Dataset for tabular data
class MyDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
# Dataloaders
trainset = MyDataset(X_train, y_train)
testset = MyDataset(X_test, y_test)
trainloader = DataLoader(trainset, batch_size=32, shuffle=True)
testloader = DataLoader(testset, batch_size=32, shuffle=False)

# %%
# Model
class AutoEncoder(nn.Module):
  def __init__(self, input_size, hidden_layers, out_act, **kwargs):
    super().__init__()
    # Layers
    self.layers  = nn.ModuleList()
    self.out_act = out_act
    self.out_params = kwargs
    # Encoder
    # Creating first layer
    self.num_encoding_layers = 0
    self.layers.append(nn.Linear(input_size, hidden_layers[0]))
    self.num_encoding_layers += 1
    self.layers.append(nn.BatchNorm1d(hidden_layers[0]))
    self.num_encoding_layers += 1
    # Creating other encoder layers specified in hidden_layers
    for i in range(1, len(hidden_layers)):
        self.layers.append(nn.Linear(hidden_layers[i-1], hidden_layers[i]))
        self.num_encoding_layers += 1
        self.layers.append(nn.BatchNorm1d(hidden_layers[i]))
        self.num_encoding_layers += 1
      
    # Decoder
    self.num_decoding_layers = 0
    for i in reversed(range(1, len(hidden_layers))):
        self.layers.append(nn.Linear(hidden_layers[i], hidden_layers[i-1]))
        self.num_decoding_layers += 1
        self.layers.append(nn.BatchNorm1d(hidden_layers[i-1]))
        self.num_decoding_layers += 1
    self.layers.append(nn.Linear(hidden_layers[0], input_size))
    self.num_decoding_layers += 1

  # Encoding
  def encode(self, x):
    for i in range(1, self.num_encoding_layers, 2):
        #print(self.layers[i-1])
        x = self.layers[i-1](x)
        #print(self.layers[i])
        x = self.layers[i](x)
        x = F.relu(x)
    return x

  # Decoding
  def decode(self, x):
    for i in range(1, self.num_decoding_layers-1, 2):
        #print(self.layers[i + self.num_encoding_layers - 1])
        x = self.layers[i + self.num_encoding_layers - 1](x)
        #print(self.layers[i + self.num_encoding_layers])
        x = self.layers[i + self.num_encoding_layers](x)
        x = F.relu(x)
    x = self.layers[-1](x)
    if self.out_act != 'mixed':
        return self.out_act(x)
    else:
        x_num = self.out_params['num_act'](x[:, :self.out_params['num_features']])
        x_cat = self.out_params['cat_act'](x[:, self.out_params['num_features']:])
        x = torch.cat((x_num, x_cat), dim=1)
        return x
    
  def forward(self, x):
    enc = self.encode(x)
    dec = self.decode(enc)
    return dec

# %%
model = AutoEncoder(227, [128, 64, 32], out_act=F.sigmoid)
print(model)
# Out:
# AutoEncoder(
#   (layers): ModuleList(
#     (0): Linear(in_features=227, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Linear(in_features=32, out_features=64, bias=True)
#     (7): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Linear(in_features=64, out_features=128, bias=True)
#     (9): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): Linear(in_features=128, out_features=227, bias=True)
#   )
# )

# %%
# Training loop
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutoEncoder(227, [128, 64, 32, 16], out_act=F.sigmoid).to(device)
criterion1 = nn.MSELoss()
criterion2 = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

epochs = 20
print_every = 40
steps = 0
train_losses, test_losses = [], []

for e in range(epochs):
  running_loss = 0
  running_loss_ = 0
  for X, y in trainloader:
    steps += 1
    X, y = X.to(device), y.to(device)
    optimizer.zero_grad()
    output = model(X)
    loss1 = criterion1(output[:, :8], y[:, :8])
    loss2 = criterion2(output[:, 8:], y[:, 8:])
    loss = loss1 + loss2
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
    running_loss_ += loss.item()

    if steps % print_every == 0:
      print(f'Epoch {e+1}/{epochs}, Step {steps}, Train Loss: {running_loss_/print_every:.3f}')
      running_loss_ = 0



  else:
    running_testloss = 0
    with torch.no_grad():
      model.eval()
      for X, y in testloader:
        X, y = X.to(device), y.to(device)
        output = model(X)
        loss1 = criterion1(output[:, :8], y[:, :8])
        loss2 = criterion2(output[:, 8:], y[:, 8:])
        loss = loss1 + loss2
        running_testloss += loss.item()
    model.train()
    train_losses.append(running_loss/len(trainloader))
    test_losses.append(running_testloss/len(testloader))
    print(f'Epoch {e+1}/{epochs}, Train Loss: {running_loss/len(trainloader):.3f}, Test Loss: {running_testloss/len(testloader):.3f}')
# Out:
# Epoch 1/20, Step 40, Train Loss: 0.468
# Epoch 1/20, Step 80, Train Loss: 0.192
# Epoch 1/20, Step 120, Train Loss: 0.141
# Epoch 1/20, Step 160, Train Loss: 0.119
# Epoch 1/20, Step 200, Train Loss: 0.109
# Epoch 1/20, Step 240, Train Loss: 0.102
# Epoch 1/20, Step 280, Train Loss: 0.098
# Epoch 1/20, Step 320, Train Loss: 0.094
# Epoch 1/20, Step 360, Train Loss: 0.091
# Epoch 1/20, Step 400, Train Loss: 0.090
# Epoch 1/20, Step 440, Train Loss: 0.085
# Epoch 1/20, Step 480, Train Loss: 0.084
# Epoch 1/20, Train Loss: 0.139, Test Loss: 0.081
# Epoch 2/20, Step 520, Train Loss: 0.083
# Epoch 2/20, Step 560, Train Loss: 0.083
# Epoch 2/20, Step 600, Train Loss: 0.080
# Epoch 2/20, Step 640, Train Loss: 0.079
# Epoch 2/20, Step 680, Train Loss: 0.079
# Epoch 2/20, Step 720, Train Loss: 0.077
# Epoch 2/20, Step 760, Train Loss: 0.077
# Epoch 2/20, Step 800, Train Loss: 0.075
# Epoch 2/20, Step 840, Train Loss: 0.075
# Epoch 2/20, Step 880, Train Loss: 0.072
# Epoch 2/20, Step 920, Train Loss: 0.073
# Epoch 2/20, Step 960, Train Loss: 0.074
# Epoch 2/20, Train Loss: 0.077, Test Loss: 0.068
# Epoch 3/20, Step 1000, Train Loss: 0.069
# Epoch 3/20, Step 1040, Train Loss: 0.071
# Epoch 3/20, Step 1080, Train Loss: 0.068
# Epoch 3/20, Step 1120, Train Loss: 0.071
# Epoch 3/20, Step 1160, Train Loss: 0.069
# Epoch 3/20, Step 1200, Train Loss: 0.067
# Epoch 3/20, Step 1240, Train Loss: 0.067
# Epoch 3/20, Step 1280, Train Loss: 0.067
# Epoch 3/20, Step 1320, Train Loss: 0.066
# Epoch 3/20, Step 1360, Train Loss: 0.066
# Epoch 3/20, Step 1400, Train Loss: 0.066
# Epoch 3/20, Step 1440, Train Loss: 0.064
# Epoch 3/20, Train Loss: 0.068, Test Loss: 0.060
# Epoch 4/20, Step 1480, Train Loss: 0.063
# Epoch 4/20, Step 1520, Train Loss: 0.063
# Epoch 4/20, Step 1560, Train Loss: 0.063
# Epoch 4/20, Step 1600, Train Loss: 0.062
# Epoch 4/20, Step 1640, Train Loss: 0.062
# Epoch 4/20, Step 1680, Train Loss: 0.061
# Epoch 4/20, Step 1720, Train Loss: 0.062
# Epoch 4/20, Step 1760, Train Loss: 0.062
# Epoch 4/20, Step 1800, Train Loss: 0.061
# Epoch 4/20, Step 1840, Train Loss: 0.062
# Epoch 4/20, Step 1880, Train Loss: 0.062
# Epoch 4/20, Step 1920, Train Loss: 0.061
# Epoch 4/20, Train Loss: 0.062, Test Loss: 0.056
# Epoch 5/20, Step 1960, Train Loss: 0.060
# Epoch 5/20, Step 2000, Train Loss: 0.058
# Epoch 5/20, Step 2040, Train Loss: 0.060
# Epoch 5/20, Step 2080, Train Loss: 0.059
# Epoch 5/20, Step 2120, Train Loss: 0.058
# Epoch 5/20, Step 2160, Train Loss: 0.058
# Epoch 5/20, Step 2200, Train Loss: 0.059
# Epoch 5/20, Step 2240, Train Loss: 0.058
# Epoch 5/20, Step 2280, Train Loss: 0.059
# Epoch 5/20, Step 2320, Train Loss: 0.057
# Epoch 5/20, Step 2360, Train Loss: 0.057
# Epoch 5/20, Step 2400, Train Loss: 0.058
# Epoch 5/20, Train Loss: 0.058, Test Loss: 0.053
# Epoch 6/20, Step 2440, Train Loss: 0.056
# Epoch 6/20, Step 2480, Train Loss: 0.057
# Epoch 6/20, Step 2520, Train Loss: 0.057
# Epoch 6/20, Step 2560, Train Loss: 0.056
# Epoch 6/20, Step 2600, Train Loss: 0.056
# Epoch 6/20, Step 2640, Train Loss: 0.057
# Epoch 6/20, Step 2680, Train Loss: 0.055
# Epoch 6/20, Step 2720, Train Loss: 0.055
# Epoch 6/20, Step 2760, Train Loss: 0.054
# Epoch 6/20, Step 2800, Train Loss: 0.055
# Epoch 6/20, Step 2840, Train Loss: 0.056
# Epoch 6/20, Step 2880, Train Loss: 0.056
# Epoch 6/20, Train Loss: 0.056, Test Loss: 0.051
# Epoch 7/20, Step 2920, Train Loss: 0.055
# Epoch 7/20, Step 2960, Train Loss: 0.055
# Epoch 7/20, Step 3000, Train Loss: 0.054
# Epoch 7/20, Step 3040, Train Loss: 0.053
# Epoch 7/20, Step 3080, Train Loss: 0.054
# Epoch 7/20, Step 3120, Train Loss: 0.054
# Epoch 7/20, Step 3160, Train Loss: 0.055
# Epoch 7/20, Step 3200, Train Loss: 0.053
# Epoch 7/20, Step 3240, Train Loss: 0.052
# Epoch 7/20, Step 3280, Train Loss: 0.053
# Epoch 7/20, Step 3320, Train Loss: 0.054
# Epoch 7/20, Step 3360, Train Loss: 0.053
# Epoch 7/20, Train Loss: 0.054, Test Loss: 0.049
# Epoch 8/20, Step 3400, Train Loss: 0.052
# Epoch 8/20, Step 3440, Train Loss: 0.052
# Epoch 8/20, Step 3480, Train Loss: 0.052
# Epoch 8/20, Step 3520, Train Loss: 0.052
# Epoch 8/20, Step 3560, Train Loss: 0.052
# Epoch 8/20, Step 3600, Train Loss: 0.052
# Epoch 8/20, Step 3640, Train Loss: 0.051
# Epoch 8/20, Step 3680, Train Loss: 0.052
# Epoch 8/20, Step 3720, Train Loss: 0.052
# Epoch 8/20, Step 3760, Train Loss: 0.052
# Epoch 8/20, Step 3800, Train Loss: 0.050
# Epoch 8/20, Step 3840, Train Loss: 0.050
# Epoch 8/20, Train Loss: 0.052, Test Loss: 0.047
# Epoch 9/20, Step 3880, Train Loss: 0.050
# Epoch 9/20, Step 3920, Train Loss: 0.050
# Epoch 9/20, Step 3960, Train Loss: 0.049
# Epoch 9/20, Step 4000, Train Loss: 0.050
# Epoch 9/20, Step 4040, Train Loss: 0.048
# Epoch 9/20, Step 4080, Train Loss: 0.049
# Epoch 9/20, Step 4120, Train Loss: 0.048
# Epoch 9/20, Step 4160, Train Loss: 0.050
# Epoch 9/20, Step 4200, Train Loss: 0.051
# Epoch 9/20, Step 4240, Train Loss: 0.050
# Epoch 9/20, Step 4280, Train Loss: 0.047
# Epoch 9/20, Step 4320, Train Loss: 0.049
# Epoch 9/20, Train Loss: 0.049, Test Loss: 0.044
# Epoch 10/20, Step 4360, Train Loss: 0.048
# Epoch 10/20, Step 4400, Train Loss: 0.047
# Epoch 10/20, Step 4440, Train Loss: 0.046
# Epoch 10/20, Step 4480, Train Loss: 0.048
# Epoch 10/20, Step 4520, Train Loss: 0.048
# Epoch 10/20, Step 4560, Train Loss: 0.047
# Epoch 10/20, Step 4600, Train Loss: 0.048
# Epoch 10/20, Step 4640, Train Loss: 0.046
# Epoch 10/20, Step 4680, Train Loss: 0.048
# Epoch 10/20, Step 4720, Train Loss: 0.048
# Epoch 10/20, Step 4760, Train Loss: 0.045
# Epoch 10/20, Step 4800, Train Loss: 0.046
# Epoch 10/20, Train Loss: 0.047, Test Loss: 0.042
# Epoch 11/20, Step 4840, Train Loss: 0.045
# Epoch 11/20, Step 4880, Train Loss: 0.045
# Epoch 11/20, Step 4920, Train Loss: 0.046
# Epoch 11/20, Step 4960, Train Loss: 0.045
# Epoch 11/20, Step 5000, Train Loss: 0.046
# Epoch 11/20, Step 5040, Train Loss: 0.045
# Epoch 11/20, Step 5080, Train Loss: 0.046
# Epoch 11/20, Step 5120, Train Loss: 0.045
# Epoch 11/20, Step 5160, Train Loss: 0.045
# Epoch 11/20, Step 5200, Train Loss: 0.044
# Epoch 11/20, Step 5240, Train Loss: 0.046
# Epoch 11/20, Step 5280, Train Loss: 0.045
# Epoch 11/20, Train Loss: 0.045, Test Loss: 0.040
# Epoch 12/20, Step 5320, Train Loss: 0.044
# Epoch 12/20, Step 5360, Train Loss: 0.042
# Epoch 12/20, Step 5400, Train Loss: 0.044
# Epoch 12/20, Step 5440, Train Loss: 0.044
# Epoch 12/20, Step 5480, Train Loss: 0.042
# Epoch 12/20, Step 5520, Train Loss: 0.043
# Epoch 12/20, Step 5560, Train Loss: 0.045
# Epoch 12/20, Step 5600, Train Loss: 0.045
# Epoch 12/20, Step 5640, Train Loss: 0.044
# Epoch 12/20, Step 5680, Train Loss: 0.043
# Epoch 12/20, Step 5720, Train Loss: 0.044
# Epoch 12/20, Step 5760, Train Loss: 0.044
# Epoch 12/20, Train Loss: 0.044, Test Loss: 0.039
# Epoch 13/20, Step 5800, Train Loss: 0.042
# Epoch 13/20, Step 5840, Train Loss: 0.044
# Epoch 13/20, Step 5880, Train Loss: 0.044
# Epoch 13/20, Step 5920, Train Loss: 0.042
# Epoch 13/20, Step 5960, Train Loss: 0.042
# Epoch 13/20, Step 6000, Train Loss: 0.041
# Epoch 13/20, Step 6040, Train Loss: 0.043
# Epoch 13/20, Step 6080, Train Loss: 0.043
# Epoch 13/20, Step 6120, Train Loss: 0.042
# Epoch 13/20, Step 6160, Train Loss: 0.042
# Epoch 13/20, Step 6200, Train Loss: 0.041
# Epoch 13/20, Step 6240, Train Loss: 0.042
# Epoch 13/20, Train Loss: 0.042, Test Loss: 0.037
# Epoch 14/20, Step 6280, Train Loss: 0.042
# Epoch 14/20, Step 6320, Train Loss: 0.042
# Epoch 14/20, Step 6360, Train Loss: 0.040
# Epoch 14/20, Step 6400, Train Loss: 0.041
# Epoch 14/20, Step 6440, Train Loss: 0.041
# Epoch 14/20, Step 6480, Train Loss: 0.041
# Epoch 14/20, Step 6520, Train Loss: 0.039
# Epoch 14/20, Step 6560, Train Loss: 0.041
# Epoch 14/20, Step 6600, Train Loss: 0.040
# Epoch 14/20, Step 6640, Train Loss: 0.041
# Epoch 14/20, Step 6680, Train Loss: 0.040
# Epoch 14/20, Step 6720, Train Loss: 0.040
# Epoch 14/20, Train Loss: 0.041, Test Loss: 0.036
# Epoch 15/20, Step 6760, Train Loss: 0.039
# Epoch 15/20, Step 6800, Train Loss: 0.040
# Epoch 15/20, Step 6840, Train Loss: 0.041
# Epoch 15/20, Step 6880, Train Loss: 0.040
# Epoch 15/20, Step 6920, Train Loss: 0.040
# Epoch 15/20, Step 6960, Train Loss: 0.040
# Epoch 15/20, Step 7000, Train Loss: 0.039
# Epoch 15/20, Step 7040, Train Loss: 0.041
# Epoch 15/20, Step 7080, Train Loss: 0.040
# Epoch 15/20, Step 7120, Train Loss: 0.040
# Epoch 15/20, Step 7160, Train Loss: 0.039
# Epoch 15/20, Step 7200, Train Loss: 0.040
# Epoch 15/20, Train Loss: 0.040, Test Loss: 0.035
# Epoch 16/20, Step 7240, Train Loss: 0.037
# Epoch 16/20, Step 7280, Train Loss: 0.040
# Epoch 16/20, Step 7320, Train Loss: 0.038
# Epoch 16/20, Step 7360, Train Loss: 0.039
# Epoch 16/20, Step 7400, Train Loss: 0.039
# Epoch 16/20, Step 7440, Train Loss: 0.038
# Epoch 16/20, Step 7480, Train Loss: 0.038
# Epoch 16/20, Step 7520, Train Loss: 0.039
# Epoch 16/20, Step 7560, Train Loss: 0.038
# Epoch 16/20, Step 7600, Train Loss: 0.038
# Epoch 16/20, Step 7640, Train Loss: 0.038
# Epoch 16/20, Step 7680, Train Loss: 0.037
# Epoch 16/20, Train Loss: 0.038, Test Loss: 0.034
# Epoch 17/20, Step 7720, Train Loss: 0.037
# Epoch 17/20, Step 7760, Train Loss: 0.037
# Epoch 17/20, Step 7800, Train Loss: 0.037
# Epoch 17/20, Step 7840, Train Loss: 0.038
# Epoch 17/20, Step 7880, Train Loss: 0.036
# Epoch 17/20, Step 7920, Train Loss: 0.039
# Epoch 17/20, Step 7960, Train Loss: 0.037
# Epoch 17/20, Step 8000, Train Loss: 0.036
# Epoch 17/20, Step 8040, Train Loss: 0.037
# Epoch 17/20, Step 8080, Train Loss: 0.036
# Epoch 17/20, Step 8120, Train Loss: 0.037
# Epoch 17/20, Step 8160, Train Loss: 0.037
# Epoch 17/20, Train Loss: 0.037, Test Loss: 0.033
# Epoch 18/20, Step 8200, Train Loss: 0.034
# Epoch 18/20, Step 8240, Train Loss: 0.036
# Epoch 18/20, Step 8280, Train Loss: 0.036
# Epoch 18/20, Step 8320, Train Loss: 0.036
# Epoch 18/20, Step 8360, Train Loss: 0.035
# Epoch 18/20, Step 8400, Train Loss: 0.036
# Epoch 18/20, Step 8440, Train Loss: 0.036
# Epoch 18/20, Step 8480, Train Loss: 0.036
# Epoch 18/20, Step 8520, Train Loss: 0.036
# Epoch 18/20, Step 8560, Train Loss: 0.036
# Epoch 18/20, Step 8600, Train Loss: 0.036
# Epoch 18/20, Step 8640, Train Loss: 0.036
# Epoch 18/20, Train Loss: 0.036, Test Loss: 0.032
# Epoch 19/20, Step 8680, Train Loss: 0.037
# Epoch 19/20, Step 8720, Train Loss: 0.035
# Epoch 19/20, Step 8760, Train Loss: 0.036
# Epoch 19/20, Step 8800, Train Loss: 0.035
# Epoch 19/20, Step 8840, Train Loss: 0.035
# Epoch 19/20, Step 8880, Train Loss: 0.034
# Epoch 19/20, Step 8920, Train Loss: 0.034
# Epoch 19/20, Step 8960, Train Loss: 0.034
# Epoch 19/20, Step 9000, Train Loss: 0.035
# Epoch 19/20, Step 9040, Train Loss: 0.033
# Epoch 19/20, Step 9080, Train Loss: 0.035
# Epoch 19/20, Step 9120, Train Loss: 0.036
# Epoch 19/20, Train Loss: 0.035, Test Loss: 0.031
# Epoch 20/20, Step 9160, Train Loss: 0.033
# Epoch 20/20, Step 9200, Train Loss: 0.033
# Epoch 20/20, Step 9240, Train Loss: 0.034
# Epoch 20/20, Step 9280, Train Loss: 0.033
# Epoch 20/20, Step 9320, Train Loss: 0.034
# Epoch 20/20, Step 9360, Train Loss: 0.034
# Epoch 20/20, Step 9400, Train Loss: 0.034
# Epoch 20/20, Step 9440, Train Loss: 0.033
# Epoch 20/20, Step 9480, Train Loss: 0.034
# Epoch 20/20, Step 9520, Train Loss: 0.034
# Epoch 20/20, Step 9560, Train Loss: 0.036
# Epoch 20/20, Step 9600, Train Loss: 0.034
# Epoch 20/20, Train Loss: 0.034, Test Loss: 0.030

# %%
# Creating a new dataset that contains all the data ordered by their indices
all_data = pd.concat([train, test], axis=0).sort_index()
X = torch.nan_to_num(torch.Tensor(all_data.values.astype('float32')))
y = torch.nan_to_num(torch.Tensor(all_data.values.astype('float32')))
dataset = MyDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=False)

# Creating a latent space on the dataset
with torch.no_grad():
    model.eval()
    full_latent_space = []
    for X, _ in tqdm(dataloader):
        latent_space = model.encode(X.to(device))
        full_latent_space.append(latent_space)

latent_space = torch.cat(full_latent_space, dim=0)
latent_space = latent_space.to('cpu').numpy()
latent_space.shape
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 534/534 [00:00<00:00, 740.67it/s]
# (17058, 16)

# %%
# Dimension reduction to 2 with PCA if neccesary
if latent_space.shape[1] != 2:
    pca_2var = PCA(n_components=2)
    latent_space_2var = pca_2var.fit_transform(latent_space)

# %%
# Function to calculate WCSS
def calculate_wcss(X, max_clusters):
    wcss = []
    for i in range(1, max_clusters):
        kmeans = KMeans(n_clusters=i, random_state=42, n_init='auto')
        kmeans.fit(X)
        wcss.append(kmeans.inertia_)
    return wcss

# Calculate WCSS for different values of k
wcss = calculate_wcss(latent_space_2var, 20)

# Use KneeLocator to find the elbow point
kneedle = KneeLocator(range(1, 20), wcss, curve='convex', direction='decreasing')
optimal_k = kneedle.elbow

# Kmeans with the optimal number of clusters
kmeans_actual = KMeans(n_clusters=optimal_k, random_state=42, n_init='auto')
kmeans_actual.fit(latent_space_2var)

# Colormap for clustering
cmap = cm.get_cmap('viridis', optimal_k)

f, ax = plt.subplots(2, 1, figsize=(6, 8))
# Plot the Elbow Method graph
ax[0].plot(range(1, 20), wcss, marker='o')
ax[0].vlines(optimal_k, ax[0].get_ylim()[0], ax[0].get_ylim()[1], linestyles='dashed')
ax[0].set_title('Elbow Method')
ax[0].set_xlabel('Number of clusters')
ax[0].set_ylabel('WCSS')
ax[1].scatter(latent_space_2var[:, 0], latent_space_2var[:, 1], c=kmeans_actual.labels_, cmap=cmap)
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=cmap(i), markersize=10) for i in range(optimal_k)]
labels = [f'Cluster {cluster}' for cluster in range(optimal_k)]
ax[1].legend(handles, labels, title='Cluster')
plt.show()
# Out:
# C:\Users\CSANADANSYS\AppData\Local\Temp\ipykernel_1404\2984411298.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis', optimal_k)
