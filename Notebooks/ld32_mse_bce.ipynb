# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from pandas.tseries.holiday import USFederalHolidayCalendar
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from torch.nn import functional as F
import torch
from torchvision import datasets, transforms
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from kneed import KneeLocator
import matplotlib.cm as cm

# %%
# Loading data
inputFeature = pd.read_csv('../Data/NIBRS_ND_2021/processed/input.csv', index_col='Unnamed: 0')
# Separating numerical and categorical features
numerical_features=['population','victim_seq_num','age_num_victim','incident_hour','incident_month','incident_day','incident_dayofmonth','incident_weekofyear']
categorical_features = ['resident_status_code','race_desc_victim',
'ethnicity_name_victim','pub_agency_name','offense_name','location_name','weapon_name'
,'injury_name','relationship_name','incident_isweekend']
# Onehot-encoding categorical features
inputFeature_1h = pd.get_dummies(inputFeature, columns=categorical_features)

# %%
# Convert object columns to numeric if they represent categories
for column in inputFeature_1h.select_dtypes(include=['object']):
    inputFeature_1h[column] = inputFeature_1h[column].astype('category').cat.codes

# Train-test split
train, test = train_test_split(inputFeature_1h, test_size=0.1, random_state=42)

# Normalizing numerical features
for feature in numerical_features:
  train[feature] = (train[feature] - train[feature].min()) / (train[feature].max() - train[feature].min())
  test[feature] = (test[feature] - test[feature].min()) / (test[feature].max() - test[feature].min())

# Converting data to tensors
X_train = torch.nan_to_num(torch.Tensor(train.values.astype(np.float32)))
y_train = torch.nan_to_num(torch.Tensor(train.values.astype(np.float32)))

X_test = torch.nan_to_num(torch.Tensor(test.values.astype(np.float32)))
y_test = torch.nan_to_num(torch.Tensor(test.values.astype(np.float32)))

# %%
# Dataset for tabular data
class MyDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
# Dataloaders
trainset = MyDataset(X_train, y_train)
testset = MyDataset(X_test, y_test)
trainloader = DataLoader(trainset, batch_size=32, shuffle=True)
testloader = DataLoader(testset, batch_size=32, shuffle=False)

# %%
# Model
class AutoEncoder(nn.Module):
  def __init__(self):
    super().__init__()
    # Layers
    # Encoder
    self.enc1 = nn.Linear(227, 128)
    self.bn1 = nn.BatchNorm1d(128)
    self.enc2 = nn.Linear(128, 64)
    self.bn2 = nn.BatchNorm1d(64)
    self.enc3 = nn.Linear(64, 32)
    self.bn3 = nn.BatchNorm1d(32)
      
    # Decoder
    self.dec1 = nn.Linear(32, 64)
    self.bn4 = nn.BatchNorm1d(64)
    self.dec2 = nn.Linear(64, 128)
    self.bn5 = nn.BatchNorm1d(128)
    self.dec3 = nn.Linear(128, 227)


  def encode(self, x):
    # Encoding
    x = self.bn1(F.relu(self.enc1(x)))
    x = self.bn2(F.relu(self.enc2(x)))
    enc = self.bn3(F.relu(self.enc3(x)))
    return enc

  def decode(self, enc):
    # Decoding
    x = self.bn4(F.relu(self.dec1(enc)))
    x = self.bn5(F.relu(self.dec2(x)))
    x = self.dec3(x)
    num_x = x[:, :8]
    cat_x = F.sigmoid(x[:, 8:])
    dec = torch.cat((num_x, cat_x), dim=1)
    return dec

  def forward(self, x):
    enc = self.encode(x)
    dec = self.decode(enc)
    return dec

# %%
model = AutoEncoder()
print(model)
# Out:
# AutoEncoder(
#   (enc1): Linear(in_features=227, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (enc2): Linear(in_features=128, out_features=64, bias=True)
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (enc3): Linear(in_features=64, out_features=32, bias=True)
#   (bn3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dec1): Linear(in_features=32, out_features=64, bias=True)
#   (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dec2): Linear(in_features=64, out_features=128, bias=True)
#   (bn5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dec3): Linear(in_features=128, out_features=227, bias=True)
# )

# %%
# Training loop
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = AutoEncoder().to(device)
criterion1 = nn.MSELoss()
criterion2 = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

epochs = 40
print_every = 40
steps = 0
train_losses, test_losses = [], []

for e in range(epochs):
  running_loss = 0
  running_loss_ = 0
  for X, y in trainloader:
    steps += 1
    X, y = X.to(device), y.to(device)
    optimizer.zero_grad()
    output = model(X)
    loss1 = criterion1(output[:, :8], y[:, :8])
    loss2 = criterion2(output[:, 8:], y[:, 8:])
    loss = loss1 + loss2
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
    running_loss_ += loss.item()

    if steps % print_every == 0:
      print(f'Epoch {e+1}/{epochs}, Step {steps}, Train Loss: {running_loss_/print_every:.3f}')
      running_loss_ = 0



  else:
    running_testloss = 0
    with torch.no_grad():
      model.eval()
      for X, y in testloader:
        X, y = X.to(device), y.to(device)
        output = model(X)
        loss1 = criterion1(output[:, :8], y[:, :8])
        loss2 = criterion2(output[:, 8:], y[:, 8:])
        loss = loss1 + loss2
        running_testloss += loss.item()
    model.train()
    train_losses.append(running_loss/len(trainloader))
    test_losses.append(running_testloss/len(testloader))
    print(f'Epoch {e+1}/{epochs}, Train Loss: {running_loss/len(trainloader):.3f}, Test Loss: {running_testloss/len(testloader):.3f}')
# Out:
# Epoch 1/40, Step 40, Train Loss: 1.065
# Epoch 1/40, Step 80, Train Loss: 0.765
# Epoch 1/40, Step 120, Train Loss: 0.444
# Epoch 1/40, Step 160, Train Loss: 0.247
# Epoch 1/40, Step 200, Train Loss: 0.164
# Epoch 1/40, Step 240, Train Loss: 0.128
# Epoch 1/40, Step 280, Train Loss: 0.113
# Epoch 1/40, Step 320, Train Loss: 0.102
# Epoch 1/40, Step 360, Train Loss: 0.094
# Epoch 1/40, Step 400, Train Loss: 0.091
# Epoch 1/40, Step 440, Train Loss: 0.088
# Epoch 1/40, Step 480, Train Loss: 0.084
# Epoch 1/40, Train Loss: 0.282, Test Loss: 0.078
# Epoch 2/40, Step 520, Train Loss: 0.080
# Epoch 2/40, Step 560, Train Loss: 0.079
# Epoch 2/40, Step 600, Train Loss: 0.078
# Epoch 2/40, Step 640, Train Loss: 0.075
# Epoch 2/40, Step 680, Train Loss: 0.075
# Epoch 2/40, Step 720, Train Loss: 0.073
# Epoch 2/40, Step 760, Train Loss: 0.071
# Epoch 2/40, Step 800, Train Loss: 0.067
# Epoch 2/40, Step 840, Train Loss: 0.067
# Epoch 2/40, Step 880, Train Loss: 0.067
# Epoch 2/40, Step 920, Train Loss: 0.067
# Epoch 2/40, Step 960, Train Loss: 0.065
# Epoch 2/40, Train Loss: 0.072, Test Loss: 0.059
# Epoch 3/40, Step 1000, Train Loss: 0.062
# Epoch 3/40, Step 1040, Train Loss: 0.061
# Epoch 3/40, Step 1080, Train Loss: 0.061
# Epoch 3/40, Step 1120, Train Loss: 0.060
# Epoch 3/40, Step 1160, Train Loss: 0.059
# Epoch 3/40, Step 1200, Train Loss: 0.058
# Epoch 3/40, Step 1240, Train Loss: 0.057
# Epoch 3/40, Step 1280, Train Loss: 0.055
# Epoch 3/40, Step 1320, Train Loss: 0.056
# Epoch 3/40, Step 1360, Train Loss: 0.055
# Epoch 3/40, Step 1400, Train Loss: 0.054
# Epoch 3/40, Step 1440, Train Loss: 0.052
# Epoch 3/40, Train Loss: 0.058, Test Loss: 0.047
# Epoch 4/40, Step 1480, Train Loss: 0.051
# Epoch 4/40, Step 1520, Train Loss: 0.052
# Epoch 4/40, Step 1560, Train Loss: 0.049
# Epoch 4/40, Step 1600, Train Loss: 0.049
# Epoch 4/40, Step 1640, Train Loss: 0.048
# Epoch 4/40, Step 1680, Train Loss: 0.049
# Epoch 4/40, Step 1720, Train Loss: 0.046
# Epoch 4/40, Step 1760, Train Loss: 0.047
# Epoch 4/40, Step 1800, Train Loss: 0.045
# Epoch 4/40, Step 1840, Train Loss: 0.045
# Epoch 4/40, Step 1880, Train Loss: 0.044
# Epoch 4/40, Step 1920, Train Loss: 0.044
# Epoch 4/40, Train Loss: 0.047, Test Loss: 0.037
# Epoch 5/40, Step 1960, Train Loss: 0.042
# Epoch 5/40, Step 2000, Train Loss: 0.040
# Epoch 5/40, Step 2040, Train Loss: 0.040
# Epoch 5/40, Step 2080, Train Loss: 0.041
# Epoch 5/40, Step 2120, Train Loss: 0.040
# Epoch 5/40, Step 2160, Train Loss: 0.041
# Epoch 5/40, Step 2200, Train Loss: 0.039
# Epoch 5/40, Step 2240, Train Loss: 0.038
# Epoch 5/40, Step 2280, Train Loss: 0.038
# Epoch 5/40, Step 2320, Train Loss: 0.037
# Epoch 5/40, Step 2360, Train Loss: 0.037
# Epoch 5/40, Step 2400, Train Loss: 0.035
# Epoch 5/40, Train Loss: 0.039, Test Loss: 0.029
# Epoch 6/40, Step 2440, Train Loss: 0.035
# Epoch 6/40, Step 2480, Train Loss: 0.033
# Epoch 6/40, Step 2520, Train Loss: 0.033
# Epoch 6/40, Step 2560, Train Loss: 0.032
# Epoch 6/40, Step 2600, Train Loss: 0.033
# Epoch 6/40, Step 2640, Train Loss: 0.031
# Epoch 6/40, Step 2680, Train Loss: 0.031
# Epoch 6/40, Step 2720, Train Loss: 0.031
# Epoch 6/40, Step 2760, Train Loss: 0.030
# Epoch 6/40, Step 2800, Train Loss: 0.029
# Epoch 6/40, Step 2840, Train Loss: 0.029
# Epoch 6/40, Step 2880, Train Loss: 0.027
# Epoch 6/40, Train Loss: 0.031, Test Loss: 0.022
# Epoch 7/40, Step 2920, Train Loss: 0.027
# Epoch 7/40, Step 2960, Train Loss: 0.026
# Epoch 7/40, Step 3000, Train Loss: 0.025
# Epoch 7/40, Step 3040, Train Loss: 0.027
# Epoch 7/40, Step 3080, Train Loss: 0.025
# Epoch 7/40, Step 3120, Train Loss: 0.025
# Epoch 7/40, Step 3160, Train Loss: 0.025
# Epoch 7/40, Step 3200, Train Loss: 0.023
# Epoch 7/40, Step 3240, Train Loss: 0.024
# Epoch 7/40, Step 3280, Train Loss: 0.024
# Epoch 7/40, Step 3320, Train Loss: 0.023
# Epoch 7/40, Step 3360, Train Loss: 0.023
# Epoch 7/40, Train Loss: 0.025, Test Loss: 0.016
# Epoch 8/40, Step 3400, Train Loss: 0.023
# Epoch 8/40, Step 3440, Train Loss: 0.021
# Epoch 8/40, Step 3480, Train Loss: 0.021
# Epoch 8/40, Step 3520, Train Loss: 0.020
# Epoch 8/40, Step 3560, Train Loss: 0.020
# Epoch 8/40, Step 3600, Train Loss: 0.021
# Epoch 8/40, Step 3640, Train Loss: 0.019
# Epoch 8/40, Step 3680, Train Loss: 0.019
# Epoch 8/40, Step 3720, Train Loss: 0.019
# Epoch 8/40, Step 3760, Train Loss: 0.019
# Epoch 8/40, Step 3800, Train Loss: 0.018
# Epoch 8/40, Step 3840, Train Loss: 0.018
# Epoch 8/40, Train Loss: 0.020, Test Loss: 0.012
# Epoch 9/40, Step 3880, Train Loss: 0.018
# Epoch 9/40, Step 3920, Train Loss: 0.017
# Epoch 9/40, Step 3960, Train Loss: 0.016
# Epoch 9/40, Step 4000, Train Loss: 0.017
# Epoch 9/40, Step 4040, Train Loss: 0.016
# Epoch 9/40, Step 4080, Train Loss: 0.016
# Epoch 9/40, Step 4120, Train Loss: 0.017
# Epoch 9/40, Step 4160, Train Loss: 0.016
# Epoch 9/40, Step 4200, Train Loss: 0.016
# Epoch 9/40, Step 4240, Train Loss: 0.016
# Epoch 9/40, Step 4280, Train Loss: 0.015
# Epoch 9/40, Step 4320, Train Loss: 0.016
# Epoch 9/40, Train Loss: 0.016, Test Loss: 0.010
# Epoch 10/40, Step 4360, Train Loss: 0.015
# Epoch 10/40, Step 4400, Train Loss: 0.016
# Epoch 10/40, Step 4440, Train Loss: 0.014
# Epoch 10/40, Step 4480, Train Loss: 0.014
# Epoch 10/40, Step 4520, Train Loss: 0.014
# Epoch 10/40, Step 4560, Train Loss: 0.015
# Epoch 10/40, Step 4600, Train Loss: 0.013
# Epoch 10/40, Step 4640, Train Loss: 0.013
# Epoch 10/40, Step 4680, Train Loss: 0.013
# Epoch 10/40, Step 4720, Train Loss: 0.014
# Epoch 10/40, Step 4760, Train Loss: 0.014
# Epoch 10/40, Step 4800, Train Loss: 0.014
# Epoch 10/40, Train Loss: 0.014, Test Loss: 0.008
# Epoch 11/40, Step 4840, Train Loss: 0.013
# Epoch 11/40, Step 4880, Train Loss: 0.013
# Epoch 11/40, Step 4920, Train Loss: 0.013
# Epoch 11/40, Step 4960, Train Loss: 0.013
# Epoch 11/40, Step 5000, Train Loss: 0.013
# Epoch 11/40, Step 5040, Train Loss: 0.013
# Epoch 11/40, Step 5080, Train Loss: 0.012
# Epoch 11/40, Step 5120, Train Loss: 0.013
# Epoch 11/40, Step 5160, Train Loss: 0.012
# Epoch 11/40, Step 5200, Train Loss: 0.012
# Epoch 11/40, Step 5240, Train Loss: 0.012
# Epoch 11/40, Step 5280, Train Loss: 0.013
# Epoch 11/40, Train Loss: 0.013, Test Loss: 0.007
# Epoch 12/40, Step 5320, Train Loss: 0.012
# Epoch 12/40, Step 5360, Train Loss: 0.011
# Epoch 12/40, Step 5400, Train Loss: 0.012
# Epoch 12/40, Step 5440, Train Loss: 0.013
# Epoch 12/40, Step 5480, Train Loss: 0.012
# Epoch 12/40, Step 5520, Train Loss: 0.012
# Epoch 12/40, Step 5560, Train Loss: 0.011
# Epoch 12/40, Step 5600, Train Loss: 0.011
# Epoch 12/40, Step 5640, Train Loss: 0.011
# Epoch 12/40, Step 5680, Train Loss: 0.012
# Epoch 12/40, Step 5720, Train Loss: 0.012
# Epoch 12/40, Step 5760, Train Loss: 0.011
# Epoch 12/40, Train Loss: 0.012, Test Loss: 0.006
# Epoch 13/40, Step 5800, Train Loss: 0.010
# Epoch 13/40, Step 5840, Train Loss: 0.011
# Epoch 13/40, Step 5880, Train Loss: 0.011
# Epoch 13/40, Step 5920, Train Loss: 0.011
# Epoch 13/40, Step 5960, Train Loss: 0.011
# Epoch 13/40, Step 6000, Train Loss: 0.011
# Epoch 13/40, Step 6040, Train Loss: 0.011
# Epoch 13/40, Step 6080, Train Loss: 0.011
# Epoch 13/40, Step 6120, Train Loss: 0.011
# Epoch 13/40, Step 6160, Train Loss: 0.010
# Epoch 13/40, Step 6200, Train Loss: 0.010
# Epoch 13/40, Step 6240, Train Loss: 0.010
# Epoch 13/40, Train Loss: 0.011, Test Loss: 0.005
# Epoch 14/40, Step 6280, Train Loss: 0.010
# Epoch 14/40, Step 6320, Train Loss: 0.010
# Epoch 14/40, Step 6360, Train Loss: 0.010
# Epoch 14/40, Step 6400, Train Loss: 0.011
# Epoch 14/40, Step 6440, Train Loss: 0.010
# Epoch 14/40, Step 6480, Train Loss: 0.011
# Epoch 14/40, Step 6520, Train Loss: 0.009
# Epoch 14/40, Step 6560, Train Loss: 0.010
# Epoch 14/40, Step 6600, Train Loss: 0.011
# Epoch 14/40, Step 6640, Train Loss: 0.010
# Epoch 14/40, Step 6680, Train Loss: 0.011
# Epoch 14/40, Step 6720, Train Loss: 0.011
# Epoch 14/40, Train Loss: 0.010, Test Loss: 0.005
# Epoch 15/40, Step 6760, Train Loss: 0.010
# Epoch 15/40, Step 6800, Train Loss: 0.011
# Epoch 15/40, Step 6840, Train Loss: 0.009
# Epoch 15/40, Step 6880, Train Loss: 0.010
# Epoch 15/40, Step 6920, Train Loss: 0.009
# Epoch 15/40, Step 6960, Train Loss: 0.009
# Epoch 15/40, Step 7000, Train Loss: 0.010
# Epoch 15/40, Step 7040, Train Loss: 0.009
# Epoch 15/40, Step 7080, Train Loss: 0.009
# Epoch 15/40, Step 7120, Train Loss: 0.011
# Epoch 15/40, Step 7160, Train Loss: 0.011
# Epoch 15/40, Step 7200, Train Loss: 0.010
# Epoch 15/40, Train Loss: 0.010, Test Loss: 0.005
# Epoch 16/40, Step 7240, Train Loss: 0.009
# Epoch 16/40, Step 7280, Train Loss: 0.009
# Epoch 16/40, Step 7320, Train Loss: 0.009
# Epoch 16/40, Step 7360, Train Loss: 0.010
# Epoch 16/40, Step 7400, Train Loss: 0.010
# Epoch 16/40, Step 7440, Train Loss: 0.009
# Epoch 16/40, Step 7480, Train Loss: 0.009
# Epoch 16/40, Step 7520, Train Loss: 0.008
# Epoch 16/40, Step 7560, Train Loss: 0.009
# Epoch 16/40, Step 7600, Train Loss: 0.009
# Epoch 16/40, Step 7640, Train Loss: 0.010
# Epoch 16/40, Step 7680, Train Loss: 0.010
# Epoch 16/40, Train Loss: 0.009, Test Loss: 0.005
# Epoch 17/40, Step 7720, Train Loss: 0.008
# Epoch 17/40, Step 7760, Train Loss: 0.009
# Epoch 17/40, Step 7800, Train Loss: 0.010
# Epoch 17/40, Step 7840, Train Loss: 0.008
# Epoch 17/40, Step 7880, Train Loss: 0.009
# Epoch 17/40, Step 7920, Train Loss: 0.009
# Epoch 17/40, Step 7960, Train Loss: 0.009
# Epoch 17/40, Step 8000, Train Loss: 0.010
# Epoch 17/40, Step 8040, Train Loss: 0.009
# Epoch 17/40, Step 8080, Train Loss: 0.009
# Epoch 17/40, Step 8120, Train Loss: 0.010
# Epoch 17/40, Step 8160, Train Loss: 0.009
# Epoch 17/40, Train Loss: 0.009, Test Loss: 0.005
# Epoch 18/40, Step 8200, Train Loss: 0.008
# Epoch 18/40, Step 8240, Train Loss: 0.009
# Epoch 18/40, Step 8280, Train Loss: 0.008
# Epoch 18/40, Step 8320, Train Loss: 0.008
# Epoch 18/40, Step 8360, Train Loss: 0.009
# Epoch 18/40, Step 8400, Train Loss: 0.009
# Epoch 18/40, Step 8440, Train Loss: 0.008
# Epoch 18/40, Step 8480, Train Loss: 0.009
# Epoch 18/40, Step 8520, Train Loss: 0.009
# Epoch 18/40, Step 8560, Train Loss: 0.009
# Epoch 18/40, Step 8600, Train Loss: 0.009
# Epoch 18/40, Step 8640, Train Loss: 0.008
# Epoch 18/40, Train Loss: 0.009, Test Loss: 0.005
# Epoch 19/40, Step 8680, Train Loss: 0.009
# Epoch 19/40, Step 8720, Train Loss: 0.009
# Epoch 19/40, Step 8760, Train Loss: 0.008
# Epoch 19/40, Step 8800, Train Loss: 0.007
# Epoch 19/40, Step 8840, Train Loss: 0.009
# Epoch 19/40, Step 8880, Train Loss: 0.008
# Epoch 19/40, Step 8920, Train Loss: 0.008
# Epoch 19/40, Step 8960, Train Loss: 0.008
# Epoch 19/40, Step 9000, Train Loss: 0.009
# Epoch 19/40, Step 9040, Train Loss: 0.008
# Epoch 19/40, Step 9080, Train Loss: 0.009
# Epoch 19/40, Step 9120, Train Loss: 0.008
# Epoch 19/40, Train Loss: 0.008, Test Loss: 0.005
# Epoch 20/40, Step 9160, Train Loss: 0.008
# Epoch 20/40, Step 9200, Train Loss: 0.008
# Epoch 20/40, Step 9240, Train Loss: 0.008
# Epoch 20/40, Step 9280, Train Loss: 0.008
# Epoch 20/40, Step 9320, Train Loss: 0.008
# Epoch 20/40, Step 9360, Train Loss: 0.008
# Epoch 20/40, Step 9400, Train Loss: 0.009
# Epoch 20/40, Step 9440, Train Loss: 0.008
# Epoch 20/40, Step 9480, Train Loss: 0.008
# Epoch 20/40, Step 9520, Train Loss: 0.009
# Epoch 20/40, Step 9560, Train Loss: 0.008
# Epoch 20/40, Step 9600, Train Loss: 0.008
# Epoch 20/40, Train Loss: 0.008, Test Loss: 0.005
# Epoch 21/40, Step 9640, Train Loss: 0.008
# Epoch 21/40, Step 9680, Train Loss: 0.008
# Epoch 21/40, Step 9720, Train Loss: 0.008
# Epoch 21/40, Step 9760, Train Loss: 0.008
# Epoch 21/40, Step 9800, Train Loss: 0.008
# Epoch 21/40, Step 9840, Train Loss: 0.007
# Epoch 21/40, Step 9880, Train Loss: 0.007
# Epoch 21/40, Step 9920, Train Loss: 0.007
# Epoch 21/40, Step 9960, Train Loss: 0.009
# Epoch 21/40, Step 10000, Train Loss: 0.008
# Epoch 21/40, Step 10040, Train Loss: 0.008
# Epoch 21/40, Step 10080, Train Loss: 0.008
# Epoch 21/40, Train Loss: 0.008, Test Loss: 0.004
# Epoch 22/40, Step 10120, Train Loss: 0.007
# Epoch 22/40, Step 10160, Train Loss: 0.009
# Epoch 22/40, Step 10200, Train Loss: 0.008
# Epoch 22/40, Step 10240, Train Loss: 0.009
# Epoch 22/40, Step 10280, Train Loss: 0.008
# Epoch 22/40, Step 10320, Train Loss: 0.008
# Epoch 22/40, Step 10360, Train Loss: 0.007
# Epoch 22/40, Step 10400, Train Loss: 0.007
# Epoch 22/40, Step 10440, Train Loss: 0.008
# Epoch 22/40, Step 10480, Train Loss: 0.008
# Epoch 22/40, Step 10520, Train Loss: 0.008
# Epoch 22/40, Step 10560, Train Loss: 0.007
# Epoch 22/40, Train Loss: 0.008, Test Loss: 0.004
# Epoch 23/40, Step 10600, Train Loss: 0.007
# Epoch 23/40, Step 10640, Train Loss: 0.007
# Epoch 23/40, Step 10680, Train Loss: 0.008
# Epoch 23/40, Step 10720, Train Loss: 0.007
# Epoch 23/40, Step 10760, Train Loss: 0.007
# Epoch 23/40, Step 10800, Train Loss: 0.008
# Epoch 23/40, Step 10840, Train Loss: 0.009
# Epoch 23/40, Step 10880, Train Loss: 0.007
# Epoch 23/40, Step 10920, Train Loss: 0.007
# Epoch 23/40, Step 10960, Train Loss: 0.008
# Epoch 23/40, Step 11000, Train Loss: 0.006
# Epoch 23/40, Step 11040, Train Loss: 0.008
# Epoch 23/40, Train Loss: 0.007, Test Loss: 0.004
# Epoch 24/40, Step 11080, Train Loss: 0.008
# Epoch 24/40, Step 11120, Train Loss: 0.007
# Epoch 24/40, Step 11160, Train Loss: 0.007
# Epoch 24/40, Step 11200, Train Loss: 0.007
# Epoch 24/40, Step 11240, Train Loss: 0.008
# Epoch 24/40, Step 11280, Train Loss: 0.007
# Epoch 24/40, Step 11320, Train Loss: 0.007
# Epoch 24/40, Step 11360, Train Loss: 0.007
# Epoch 24/40, Step 11400, Train Loss: 0.007
# Epoch 24/40, Step 11440, Train Loss: 0.007
# Epoch 24/40, Step 11480, Train Loss: 0.007
# Epoch 24/40, Step 11520, Train Loss: 0.007
# Epoch 24/40, Train Loss: 0.007, Test Loss: 0.004
# Epoch 25/40, Step 11560, Train Loss: 0.007
# Epoch 25/40, Step 11600, Train Loss: 0.007
# Epoch 25/40, Step 11640, Train Loss: 0.007
# Epoch 25/40, Step 11680, Train Loss: 0.007
# Epoch 25/40, Step 11720, Train Loss: 0.007
# Epoch 25/40, Step 11760, Train Loss: 0.008
# Epoch 25/40, Step 11800, Train Loss: 0.008
# Epoch 25/40, Step 11840, Train Loss: 0.008
# Epoch 25/40, Step 11880, Train Loss: 0.008
# Epoch 25/40, Step 11920, Train Loss: 0.008
# Epoch 25/40, Step 11960, Train Loss: 0.008
# Epoch 25/40, Step 12000, Train Loss: 0.007
# Epoch 25/40, Train Loss: 0.007, Test Loss: 0.004
# Epoch 26/40, Step 12040, Train Loss: 0.007
# Epoch 26/40, Step 12080, Train Loss: 0.007
# Epoch 26/40, Step 12120, Train Loss: 0.007
# Epoch 26/40, Step 12160, Train Loss: 0.007
# Epoch 26/40, Step 12200, Train Loss: 0.007
# Epoch 26/40, Step 12240, Train Loss: 0.007
# Epoch 26/40, Step 12280, Train Loss: 0.007
# Epoch 26/40, Step 12320, Train Loss: 0.007
# Epoch 26/40, Step 12360, Train Loss: 0.007
# Epoch 26/40, Step 12400, Train Loss: 0.007
# Epoch 26/40, Step 12440, Train Loss: 0.008
# Epoch 26/40, Step 12480, Train Loss: 0.008
# Epoch 26/40, Train Loss: 0.007, Test Loss: 0.003
# Epoch 27/40, Step 12520, Train Loss: 0.006
# Epoch 27/40, Step 12560, Train Loss: 0.006
# Epoch 27/40, Step 12600, Train Loss: 0.007
# Epoch 27/40, Step 12640, Train Loss: 0.007
# Epoch 27/40, Step 12680, Train Loss: 0.007
# Epoch 27/40, Step 12720, Train Loss: 0.007
# Epoch 27/40, Step 12760, Train Loss: 0.007
# Epoch 27/40, Step 12800, Train Loss: 0.007
# Epoch 27/40, Step 12840, Train Loss: 0.007
# Epoch 27/40, Step 12880, Train Loss: 0.006
# Epoch 27/40, Step 12920, Train Loss: 0.006
# Epoch 27/40, Step 12960, Train Loss: 0.007
# Epoch 27/40, Train Loss: 0.007, Test Loss: 0.003
# Epoch 28/40, Step 13000, Train Loss: 0.006
# Epoch 28/40, Step 13040, Train Loss: 0.007
# Epoch 28/40, Step 13080, Train Loss: 0.007
# Epoch 28/40, Step 13120, Train Loss: 0.007
# Epoch 28/40, Step 13160, Train Loss: 0.007
# Epoch 28/40, Step 13200, Train Loss: 0.007
# Epoch 28/40, Step 13240, Train Loss: 0.007
# Epoch 28/40, Step 13280, Train Loss: 0.007
# Epoch 28/40, Step 13320, Train Loss: 0.007
# Epoch 28/40, Step 13360, Train Loss: 0.007
# Epoch 28/40, Step 13400, Train Loss: 0.007
# Epoch 28/40, Step 13440, Train Loss: 0.007
# Epoch 28/40, Train Loss: 0.007, Test Loss: 0.004
# Epoch 29/40, Step 13480, Train Loss: 0.006
# Epoch 29/40, Step 13520, Train Loss: 0.007
# Epoch 29/40, Step 13560, Train Loss: 0.007
# Epoch 29/40, Step 13600, Train Loss: 0.006
# Epoch 29/40, Step 13640, Train Loss: 0.006
# Epoch 29/40, Step 13680, Train Loss: 0.006
# Epoch 29/40, Step 13720, Train Loss: 0.007
# Epoch 29/40, Step 13760, Train Loss: 0.007
# Epoch 29/40, Step 13800, Train Loss: 0.007
# Epoch 29/40, Step 13840, Train Loss: 0.007
# Epoch 29/40, Step 13880, Train Loss: 0.006
# Epoch 29/40, Step 13920, Train Loss: 0.007
# Epoch 29/40, Train Loss: 0.007, Test Loss: 0.004
# Epoch 30/40, Step 13960, Train Loss: 0.006
# Epoch 30/40, Step 14000, Train Loss: 0.006
# Epoch 30/40, Step 14040, Train Loss: 0.006
# Epoch 30/40, Step 14080, Train Loss: 0.006
# Epoch 30/40, Step 14120, Train Loss: 0.006
# Epoch 30/40, Step 14160, Train Loss: 0.006
# Epoch 30/40, Step 14200, Train Loss: 0.007
# Epoch 30/40, Step 14240, Train Loss: 0.007
# Epoch 30/40, Step 14280, Train Loss: 0.007
# Epoch 30/40, Step 14320, Train Loss: 0.007
# Epoch 30/40, Step 14360, Train Loss: 0.006
# Epoch 30/40, Step 14400, Train Loss: 0.007
# Epoch 30/40, Train Loss: 0.007, Test Loss: 0.004
# Epoch 31/40, Step 14440, Train Loss: 0.007
# Epoch 31/40, Step 14480, Train Loss: 0.007
# Epoch 31/40, Step 14520, Train Loss: 0.006
# Epoch 31/40, Step 14560, Train Loss: 0.006
# Epoch 31/40, Step 14600, Train Loss: 0.006
# Epoch 31/40, Step 14640, Train Loss: 0.007
# Epoch 31/40, Step 14680, Train Loss: 0.006
# Epoch 31/40, Step 14720, Train Loss: 0.006
# Epoch 31/40, Step 14760, Train Loss: 0.006
# Epoch 31/40, Step 14800, Train Loss: 0.006
# Epoch 31/40, Step 14840, Train Loss: 0.007
# Epoch 31/40, Step 14880, Train Loss: 0.006
# Epoch 31/40, Train Loss: 0.006, Test Loss: 0.003
# Epoch 32/40, Step 14920, Train Loss: 0.006
# Epoch 32/40, Step 14960, Train Loss: 0.006
# Epoch 32/40, Step 15000, Train Loss: 0.006
# Epoch 32/40, Step 15040, Train Loss: 0.006
# Epoch 32/40, Step 15080, Train Loss: 0.006
# Epoch 32/40, Step 15120, Train Loss: 0.007
# Epoch 32/40, Step 15160, Train Loss: 0.007
# Epoch 32/40, Step 15200, Train Loss: 0.006
# Epoch 32/40, Step 15240, Train Loss: 0.006
# Epoch 32/40, Step 15280, Train Loss: 0.006
# Epoch 32/40, Step 15320, Train Loss: 0.006
# Epoch 32/40, Step 15360, Train Loss: 0.006
# Epoch 32/40, Train Loss: 0.006, Test Loss: 0.003
# Epoch 33/40, Step 15400, Train Loss: 0.006
# Epoch 33/40, Step 15440, Train Loss: 0.006
# Epoch 33/40, Step 15480, Train Loss: 0.006
# Epoch 33/40, Step 15520, Train Loss: 0.007
# Epoch 33/40, Step 15560, Train Loss: 0.006
# Epoch 33/40, Step 15600, Train Loss: 0.006
# Epoch 33/40, Step 15640, Train Loss: 0.006
# Epoch 33/40, Step 15680, Train Loss: 0.007
# Epoch 33/40, Step 15720, Train Loss: 0.006
# Epoch 33/40, Step 15760, Train Loss: 0.006
# Epoch 33/40, Step 15800, Train Loss: 0.005
# Epoch 33/40, Step 15840, Train Loss: 0.006
# Epoch 33/40, Train Loss: 0.006, Test Loss: 0.003
# Epoch 34/40, Step 15880, Train Loss: 0.006
# Epoch 34/40, Step 15920, Train Loss: 0.006
# Epoch 34/40, Step 15960, Train Loss: 0.006
# Epoch 34/40, Step 16000, Train Loss: 0.007
# Epoch 34/40, Step 16040, Train Loss: 0.006
# Epoch 34/40, Step 16080, Train Loss: 0.006
# Epoch 34/40, Step 16120, Train Loss: 0.006
# Epoch 34/40, Step 16160, Train Loss: 0.005
# Epoch 34/40, Step 16200, Train Loss: 0.006
# Epoch 34/40, Step 16240, Train Loss: 0.006
# Epoch 34/40, Step 16280, Train Loss: 0.007
# Epoch 34/40, Step 16320, Train Loss: 0.006
# Epoch 34/40, Train Loss: 0.006, Test Loss: 0.003
# Epoch 35/40, Step 16360, Train Loss: 0.006
# Epoch 35/40, Step 16400, Train Loss: 0.006
# Epoch 35/40, Step 16440, Train Loss: 0.007
# Epoch 35/40, Step 16480, Train Loss: 0.006
# Epoch 35/40, Step 16520, Train Loss: 0.006
# Epoch 35/40, Step 16560, Train Loss: 0.005
# Epoch 35/40, Step 16600, Train Loss: 0.006
# Epoch 35/40, Step 16640, Train Loss: 0.006
# Epoch 35/40, Step 16680, Train Loss: 0.006
# Epoch 35/40, Step 16720, Train Loss: 0.006
# Epoch 35/40, Step 16760, Train Loss: 0.006
# Epoch 35/40, Step 16800, Train Loss: 0.006
# Epoch 35/40, Train Loss: 0.006, Test Loss: 0.004
# Epoch 36/40, Step 16840, Train Loss: 0.007
# Epoch 36/40, Step 16880, Train Loss: 0.005
# Epoch 36/40, Step 16920, Train Loss: 0.007
# Epoch 36/40, Step 16960, Train Loss: 0.006
# Epoch 36/40, Step 17000, Train Loss: 0.006
# Epoch 36/40, Step 17040, Train Loss: 0.006
# Epoch 36/40, Step 17080, Train Loss: 0.006
# Epoch 36/40, Step 17120, Train Loss: 0.006
# Epoch 36/40, Step 17160, Train Loss: 0.006
# Epoch 36/40, Step 17200, Train Loss: 0.006
# Epoch 36/40, Step 17240, Train Loss: 0.007
# Epoch 36/40, Step 17280, Train Loss: 0.006
# Epoch 36/40, Train Loss: 0.006, Test Loss: 0.003
# Epoch 37/40, Step 17320, Train Loss: 0.006
# Epoch 37/40, Step 17360, Train Loss: 0.005
# Epoch 37/40, Step 17400, Train Loss: 0.006
# Epoch 37/40, Step 17440, Train Loss: 0.006
# Epoch 37/40, Step 17480, Train Loss: 0.006
# Epoch 37/40, Step 17520, Train Loss: 0.005
# Epoch 37/40, Step 17560, Train Loss: 0.006
# Epoch 37/40, Step 17600, Train Loss: 0.006
# Epoch 37/40, Step 17640, Train Loss: 0.006
# Epoch 37/40, Step 17680, Train Loss: 0.006
# Epoch 37/40, Step 17720, Train Loss: 0.006
# Epoch 37/40, Step 17760, Train Loss: 0.006
# Epoch 37/40, Train Loss: 0.006, Test Loss: 0.003
# Epoch 38/40, Step 17800, Train Loss: 0.006
# Epoch 38/40, Step 17840, Train Loss: 0.006
# Epoch 38/40, Step 17880, Train Loss: 0.006
# Epoch 38/40, Step 17920, Train Loss: 0.006
# Epoch 38/40, Step 17960, Train Loss: 0.006
# Epoch 38/40, Step 18000, Train Loss: 0.006
# Epoch 38/40, Step 18040, Train Loss: 0.005
# Epoch 38/40, Step 18080, Train Loss: 0.005
# Epoch 38/40, Step 18120, Train Loss: 0.006
# Epoch 38/40, Step 18160, Train Loss: 0.006
# Epoch 38/40, Step 18200, Train Loss: 0.006
# Epoch 38/40, Step 18240, Train Loss: 0.006
# Epoch 38/40, Train Loss: 0.006, Test Loss: 0.003
# Epoch 39/40, Step 18280, Train Loss: 0.006
# Epoch 39/40, Step 18320, Train Loss: 0.006
# Epoch 39/40, Step 18360, Train Loss: 0.006
# Epoch 39/40, Step 18400, Train Loss: 0.005
# Epoch 39/40, Step 18440, Train Loss: 0.006
# Epoch 39/40, Step 18480, Train Loss: 0.005
# Epoch 39/40, Step 18520, Train Loss: 0.005
# Epoch 39/40, Step 18560, Train Loss: 0.006
# Epoch 39/40, Step 18600, Train Loss: 0.006
# Epoch 39/40, Step 18640, Train Loss: 0.006
# Epoch 39/40, Step 18680, Train Loss: 0.006
# Epoch 39/40, Step 18720, Train Loss: 0.006
# Epoch 39/40, Train Loss: 0.006, Test Loss: 0.003
# Epoch 40/40, Step 18760, Train Loss: 0.006
# Epoch 40/40, Step 18800, Train Loss: 0.006
# Epoch 40/40, Step 18840, Train Loss: 0.006
# Epoch 40/40, Step 18880, Train Loss: 0.005
# Epoch 40/40, Step 18920, Train Loss: 0.006
# Epoch 40/40, Step 18960, Train Loss: 0.006
# Epoch 40/40, Step 19000, Train Loss: 0.005
# Epoch 40/40, Step 19040, Train Loss: 0.005
# Epoch 40/40, Step 19080, Train Loss: 0.005
# Epoch 40/40, Step 19120, Train Loss: 0.006
# Epoch 40/40, Step 19160, Train Loss: 0.005
# Epoch 40/40, Step 19200, Train Loss: 0.005
# Epoch 40/40, Train Loss: 0.006, Test Loss: 0.003

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend()
plt.show()

# %%
with torch.no_grad():
    model.eval()
    repro = model(X_test[0:1].to(device))
    repro_ = model(X_train[0:1].to(device))

# %%
all_data = pd.concat([train, test], axis=0).sort_index()
X = torch.nan_to_num(torch.Tensor(all_data.values.astype('float32')))
y = torch.nan_to_num(torch.Tensor(all_data.values.astype('float32')))
dataset = MyDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=False)

with torch.no_grad():
    model.eval()
    full_latent_space = []
    for X, _ in tqdm(dataloader):
        latent_space = model.encode(X.to(device))
        full_latent_space.append(latent_space)

latent_space = torch.cat(full_latent_space, dim=0)
latent_space = latent_space.to('cpu').numpy()
latent_space.shape
# Out:
# 100%|██████████| 534/534 [00:01<00:00, 501.96it/s]
# (17058, 32)

# %%
# Dimension reduction to 2 with PCA
pca_2var = PCA(n_components=2)
latent_space_2var = pca_2var.fit_transform(latent_space)

# Function to calculate WCSS
def calculate_wcss(X, max_clusters):
    wcss = []
    for i in range(1, max_clusters):
        kmeans = KMeans(n_clusters=i, random_state=42, n_init='auto')
        kmeans.fit(X)
        wcss.append(kmeans.inertia_)
    return wcss

# Calculate WCSS for different values of k
wcss = calculate_wcss(latent_space_2var, 20)

# Use KneeLocator to find the elbow point
kneedle = KneeLocator(range(1, 20), wcss, curve='convex', direction='decreasing')
optimal_k = kneedle.elbow

# Kmeans with the optimal number of clusters
kmeans_actual = KMeans(n_clusters=optimal_k, random_state=42, n_init='auto')
kmeans_actual.fit(latent_space_2var)

# Colormap for clustering
cmap = cm.get_cmap('viridis', optimal_k)

f, ax = plt.subplots(2, 1, figsize=(6, 8))
# Plot the Elbow Method graph
ax[0].plot(range(1, 20), wcss, marker='o')
ax[0].vlines(optimal_k, ax[0].get_ylim()[0], ax[0].get_ylim()[1], linestyles='dashed')
ax[0].set_title('Elbow Method')
ax[0].set_xlabel('Number of clusters')
ax[0].set_ylabel('WCSS')
ax[1].scatter(latent_space_2var[:, 0], latent_space_2var[:, 1], c=kmeans_actual.labels_, cmap=cmap)
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=cmap(i), markersize=10) for i in range(optimal_k)]
labels = [f'Cluster {cluster}' for cluster in range(optimal_k)]
ax[1].legend(handles, labels, title='Cluster')
plt.show()
# Out:
# C:\Users\CSANADANSYS\AppData\Local\Temp\ipykernel_18096\1567224446.py:26: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis', optimal_k)
